# %%
from utils import read_data, plot_smoothed_scores_wip
import matplotlib.pyplot as plt
import numpy as np

# %%
# set hyperparameters here

learnrate = 0.01
gam = 0.99
runs = 8
ep_num = 2000
save_data_cadence = 500
smoothen_over = 11
if save_data_cadence>ep_num:
    print("WARNING : data will not get saved if save cadence is more than ep_num")

# bookkeeping
fname = "reinforce_v1_lr"+"{:.4f}".format(learnrate)[-4:]+"_g"+"{:.4f}".format(gam)[-4:]+"_runs{:1d}_eps".format(runs)+str(ep_num)
    
# read data
score_stack = read_data(fname)
    
# plot results
plot_smoothed_scores_wip(score_stack, sav_window = smoothen_over, avg_plot = 1, save = 0, fname = fname)
# Out:
# working on average plot
# C:\Users\ambar\Documents\GitHub\RLA3\dotpy_code\utils.py:93: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# C:\Users\ambar\Documents\GitHub\RLA3\dotpy_code\utils.py:119: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
