# %%
import gym
import tensorflow as tf
from collections import deque
import numpy as np
from random import sample, randint
from tensorflow import keras
import matplotlib.pyplot as plt
from keras.utils.np_utils import to_categorical
import os
import glob
import tensorflow_probability as tfp
from tensorflow.keras.layers import Dense
from scipy.signal import savgol_filter

plt.rcParams['figure.figsize'] = (15, 7)
plt.rcParams.update({'font.size': 14})

# %%
'''
convenience functions
'''

def smooth(y, window, poly=1):
    '''
    y: vector to be smoothed 
    window: size of the smoothing window '''
    return savgol_filter(y,window,poly)

def save_data(data, ep_num, ep, lr, gamma):
    if ep_num > ep:
        temp = data[-1]
        temp = np.pad(temp,(0,ep_num-len(temp)),mode = 'constant',constant_values = (np.nan))
        data[-1] = temp
    fname = "reinforce_v1_lr"+"{:.4f}".format(lr)[-4:]+"_g"+"{:.4f}".format(gamma)[-4:]+"_runs{:1d}_eps".format(runs)+str(ep_num)+".csv"
    np.savetxt(fname, data, delimiter = "," )
    print("data saved in file {}".format(fname))
    if ep_num == ep:
        plot_smoothed_scores(score_stack)
        
def plot_smoothed_scores(data, save = 1, fname = "demo.pdf"):
    for run, scores in enumerate(data):
        avg_score_hist = smooth(scores,smoothen_over)
        plt.plot(avg_score_hist, label = "run "+str(run+1))
    plt.xlabel("Episodes")
    plt.ylabel("Rewards")
    avg = np.nanmean(data, axis = 0)
    plt.plot(avg, label = "average over "+str(len(data))+" runs")
    plt.legend()
    if save:
        plt.savefig(fname)
    plt.show()

# %% [markdown]
# cwd = os.getcwd()
# if cwd == "/content":
#     from google.colab import drive
# print("cwd is :", cwd)
# def printdocs(pname):
#     exec("print("+str(pname)+".__doc__)")
#
# if cwd == "/content":
#     drive.mount('/content/drive')
#     !ls /content/drive/MyDrive/data/RLA3_data
#     %cd /content/drive/MyDrive/data/RLA3_data
#     from Helper import argmax, softmax
# else:
#     print("cwd is :", cwd)
#
# print("argmax docs :", argmax.__doc__)
# print("softmax docs :", softmax.__doc__)

# %%
class policy_network(keras.Model):
    def __init__(self, n_states, n_actions, ):
        super().__init__()
        self.n_actions = n_actions
        self.ip = keras.layers.Flatten(input_shape = n_states)
        self.l1 = keras.layers.Dense(24, kernel_initializer = tf.keras.initializers.HeUniform(seed=None), activation="relu")
        self.l2 = keras.layers.Dense(24, kernel_initializer = tf.keras.initializers.HeUniform(seed=None), activation="relu")
        self.l3 = keras.layers.Dense(24, kernel_initializer = tf.keras.initializers.HeUniform(seed=None), activation="relu")
        self.op = keras.layers.Dense(n_actions, activation="softmax")
#     def __init__(self, n_actions, fc1_dims=256, fc2_dims=256):
#         super(policy_network, self).__init__()
#         self.fc1_dims = fc1_dims
#         self.fc2_dims = fc2_dims
#         self.n_actions = n_actions

#         self.fc1 = Dense(self.fc1_dims, activation='relu')
#         self.fc2 = Dense(self.fc2_dims, activation='relu')
#         self.pi = Dense(n_actions, activation='softmax')

    def call(self, state, ):
        fp = self.ip(state)
        fp = self.l1(fp)
        fp = self.l2(fp)
        fp = self.l3(fp)
        policy = self.op(fp)
        return policy

#     def call(self, state):
#         value = self.fc1(state)
#         value = self.fc2(value)

#         pi = self.pi(value)

#         return pi

# %%
class agent():
    def __init__(self, n_actions, n_states, lr = 0.003, gamma = 0.99,  ):
        self.lr = lr
        self.gamma = gamma
        self.n_actions = n_actions
        self.n_states = n_states
        self.states = []
        self.actions = []
        self.rewards = []
        self.pi = policy_network(n_states = self.n_states, n_actions = n_actions)                    # check
#         self.pi = policy_network(n_actions = n_actions)
        self.pi.compile(optimizer = keras.optimizers.Adam(learning_rate = self.lr))                  # check

    def get_act(self, state, ):
        '''takes a state and returns a tensor of action categorical probabilities'''
        state_t = tf.convert_to_tensor([state], dtype = tf.float32)
        probs = self.pi(state_t)
        cat_probs = tfp.distributions.Categorical(probs = probs)
        action = cat_probs.sample()
#         print(action.numpy()[0])
        
        return action.numpy()[0]
    
#         state = tf.convert_to_tensor([observation], dtype=tf.float32)
#         probs = self.policy(state)
#         action_probs = tfp.distributions.Categorical(probs=probs)
#         action = action_probs.sample()
#         print(action.numpy()[0])
#         return action.numpy()

    def remember(self, state, action, reward, ):
        self.states.append(state)
        self.actions.append(action)
        self.rewards.append(reward)

    def learn(self):
        actions_t = tf.convert_to_tensor(self.actions, dtype = tf.float32)
        rewards_arr = np.array(self.rewards)

        returns = np.zeros_like(rewards_arr)
        for state_id in range(returns.shape[-1]):
            returns_ds = 0
            discount_factor = 1
            for state_id_ds in range(state_id, returns.shape[-1]):
                returns_ds += rewards_arr[state_id_ds]*discount_factor
                discount_factor *= self.gamma
                
            returns[state_id] = returns_ds

        with tf.GradientTape() as tape:
            loss = 0
            for state_id, (return_g, state_g) in enumerate(zip(returns, self.states)):
                state_g = tf.convert_to_tensor([state_g], dtype = tf.float32)
                probabilities = self.pi(state_g)
                action_probabilities = tfp.distributions.Categorical(probs = probabilities)
                log_probabilities = action_probabilities.log_prob(actions_t[state_id])
                loss += -return_g * tf.squeeze(log_probabilities)

        grad = tape.gradient(loss, self.pi.trainable_variables)
        self.pi.optimizer.apply_gradients(zip(grad, self.pi.trainable_variables))

        self.states = []
        self.actions = []
        self.rewards = []

# %%
# learnrate = 0.001
# gam = 0.99
# runs = 8
# ep_num = 2000
# save_data_cadence = 200
# smoothen_over = 11
# if save_data_cadence>ep_num:
#     print("WARNING : data will not get saved if save cadence is more than ep_num")


# testing
learnrate = 0.001
gam = 0.99
runs = 8
ep_num = 300
save_data_cadence = 100
smoothen_over = 11
if save_data_cadence>ep_num:
    print("WARNING : data will not get saved if save cadence is more than ep_num")

# %%
if __name__ == "__main__":
    
    score_stack = []
    # run loop
    for run_num in range(runs):
        
        print("\n\n\n\nbeginning run number {}".format(run_num))

        # initialise environment
        env = gym.make('CartPole-v1')

        # initialize agent
        agent_007 = agent(lr = learnrate, gamma = gam, n_actions = env.action_space.n, n_states = env.observation_space.shape)

        # list to maintain score
        score_hist = []
        score_stack.append(score_hist)
        
        # episode loop
        for ep in range(ep_num):
            done = False
            score = 0
            s = env.reset()

            # step loop
            while not done:
                a = agent_007.get_act(s)
                s_next,reward,done,_ = env.step(a)
                agent_007.remember(s,a,reward)
                s = s_next
                score += reward
#                 env.render()

            # append score to score list
            score_hist.append(score)

            # make agent learn
            agent_007.learn()
            avg_score = np.mean(score_hist[-100:])
            print('episode: ', ep,'score: %.1f' % score,
                ', average score %.1f' % avg_score)

            if (ep+1) % save_data_cadence == 0:
                score_stack[-1] = score_hist
                save_data(score_stack, ep_num, ep, learnrate, gam)

plot_smoothed_scores(score_stack)
# Out:
# beginning run number 0
# episode:  0 score: 32.0 , average score 32.0
# episode:  1 score: 13.0 , average score 22.5
# episode:  2 score: 33.0 , average score 26.0
# episode:  3 score: 37.0 , average score 28.8
# episode:  4 score: 25.0 , average score 28.0
# episode:  5 score: 24.0 , average score 27.3
# episode:  6 score: 37.0 , average score 28.7
# episode:  7 score: 23.0 , average score 28.0
# episode:  8 score: 14.0 , average score 26.4
# episode:  9 score: 41.0 , average score 27.9
# episode:  10 score: 28.0 , average score 27.9
# episode:  11 score: 38.0 , average score 28.8
# episode:  12 score: 30.0 , average score 28.8
# episode:  13 score: 18.0 , average score 28.1
# episode:  14 score: 25.0 , average score 27.9
# episode:  15 score: 52.0 , average score 29.4
# episode:  16 score: 29.0 , average score 29.4
# episode:  17 score: 29.0 , average score 29.3
# episode:  18 score: 18.0 , average score 28.7
# episode:  19 score: 13.0 , average score 27.9
# episode:  20 score: 24.0 , average score 27.8
# episode:  21 score: 15.0 , average score 27.2
# episode:  22 score: 14.0 , average score 26.6
# episode:  23 score: 19.0 , average score 26.3
# episode:  24 score: 18.0 , average score 26.0
# episode:  25 score: 21.0 , average score 25.8
# episode:  26 score: 46.0 , average score 26.5
# episode:  27 score: 16.0 , average score 26.1
# episode:  28 score: 16.0 , average score 25.8
# episode:  29 score: 24.0 , average score 25.7
# episode:  30 score: 36.0 , average score 26.1
# episode:  31 score: 36.0 , average score 26.4
# episode:  32 score: 31.0 , average score 26.5
# episode:  33 score: 25.0 , average score 26.5
# episode:  34 score: 54.0 , average score 27.3
# episode:  35 score: 58.0 , average score 28.1
# episode:  36 score: 30.0 , average score 28.2
# episode:  37 score: 55.0 , average score 28.9
# episode:  38 score: 14.0 , average score 28.5
# episode:  39 score: 82.0 , average score 29.8
# episode:  40 score: 27.0 , average score 29.8
# episode:  41 score: 20.0 , average score 29.5
# episode:  42 score: 30.0 , average score 29.5
# episode:  43 score: 41.0 , average score 29.8
# episode:  44 score: 36.0 , average score 29.9
# episode:  45 score: 13.0 , average score 29.6
# episode:  46 score: 20.0 , average score 29.4
# episode:  47 score: 34.0 , average score 29.5
# episode:  48 score: 41.0 , average score 29.7
# episode:  49 score: 24.0 , average score 29.6
# episode:  50 score: 19.0 , average score 29.4
# episode:  51 score: 36.0 , average score 29.5
# episode:  52 score: 30.0 , average score 29.5
# episode:  53 score: 26.0 , average score 29.4
# episode:  54 score: 63.0 , average score 30.1
# episode:  55 score: 13.0 , average score 29.8
# episode:  56 score: 75.0 , average score 30.5
# episode:  57 score: 54.0 , average score 30.9
# episode:  58 score: 16.0 , average score 30.7
# episode:  59 score: 43.0 , average score 30.9
# episode:  60 score: 48.0 , average score 31.2
# episode:  61 score: 17.0 , average score 31.0
# episode:  62 score: 33.0 , average score 31.0
# episode:  63 score: 20.0 , average score 30.8
# episode:  64 score: 21.0 , average score 30.7
# episode:  65 score: 24.0 , average score 30.6
# episode:  66 score: 31.0 , average score 30.6
# episode:  67 score: 17.0 , average score 30.4
# episode:  68 score: 33.0 , average score 30.4
# episode:  69 score: 25.0 , average score 30.3
# episode:  70 score: 15.0 , average score 30.1
# episode:  71 score: 31.0 , average score 30.1
# episode:  72 score: 35.0 , average score 30.2
# episode:  73 score: 71.0 , average score 30.7
# episode:  74 score: 38.0 , average score 30.8
# episode:  75 score: 31.0 , average score 30.8
# episode:  76 score: 42.0 , average score 31.0
# episode:  77 score: 27.0 , average score 30.9
# episode:  78 score: 40.0 , average score 31.1
# episode:  79 score: 50.0 , average score 31.3
# episode:  80 score: 55.0 , average score 31.6
# episode:  81 score: 83.0 , average score 32.2
# episode:  82 score: 32.0 , average score 32.2
# episode:  83 score: 29.0 , average score 32.2
# episode:  84 score: 42.0 , average score 32.3
# episode:  85 score: 84.0 , average score 32.9
# episode:  86 score: 34.0 , average score 32.9
# episode:  87 score: 14.0 , average score 32.7
# episode:  88 score: 27.0 , average score 32.6
# episode:  89 score: 33.0 , average score 32.6
# episode:  90 score: 24.0 , average score 32.5
# episode:  91 score: 12.0 , average score 32.3
# episode:  92 score: 43.0 , average score 32.4
# episode:  93 score: 49.0 , average score 32.6
# episode:  94 score: 44.0 , average score 32.7
# episode:  95 score: 37.0 , average score 32.8
# episode:  96 score: 50.0 , average score 32.9
# episode:  97 score: 18.0 , average score 32.8
# episode:  98 score: 37.0 , average score 32.8
# episode:  99 score: 72.0 , average score 33.2
# data saved in file reinforce_v1_lr0010_g9900_runs8_eps300.csv
# episode:  100 score: 34.0 , average score 33.2
# episode:  101 score: 55.0 , average score 33.7
# episode:  102 score: 48.0 , average score 33.8
# episode:  103 score: 70.0 , average score 34.1
# episode:  104 score: 95.0 , average score 34.8
# episode:  105 score: 17.0 , average score 34.8
# episode:  106 score: 60.0 , average score 35.0
# episode:  107 score: 62.0 , average score 35.4
# episode:  108 score: 23.0 , average score 35.5
# episode:  109 score: 31.0 , average score 35.4
# episode:  110 score: 38.0 , average score 35.5
# episode:  111 score: 70.0 , average score 35.8
# episode:  112 score: 72.0 , average score 36.2
# episode:  113 score: 85.0 , average score 36.9
# episode:  114 score: 51.0 , average score 37.1
# episode:  115 score: 25.0 , average score 36.9
# episode:  116 score: 29.0 , average score 36.9
# episode:  117 score: 85.0 , average score 37.4
# episode:  118 score: 77.0 , average score 38.0
# episode:  119 score: 136.0 , average score 39.3
# episode:  120 score: 40.0 , average score 39.4
# episode:  121 score: 133.0 , average score 40.6
# episode:  122 score: 67.0 , average score 41.1
# episode:  123 score: 34.0 , average score 41.3
# episode:  124 score: 44.0 , average score 41.5
# episode:  125 score: 45.0 , average score 41.8
# episode:  126 score: 58.0 , average score 41.9
# episode:  127 score: 22.0 , average score 42.0
# episode:  128 score: 45.0 , average score 42.2
# episode:  129 score: 48.0 , average score 42.5
# episode:  130 score: 72.0 , average score 42.9
# episode:  131 score: 115.0 , average score 43.6
# episode:  132 score: 32.0 , average score 43.6
# episode:  133 score: 119.0 , average score 44.6
# episode:  134 score: 115.0 , average score 45.2
# episode:  135 score: 19.0 , average score 44.8
# episode:  136 score: 21.0 , average score 44.7
# episode:  137 score: 72.0 , average score 44.9
# episode:  138 score: 44.0 , average score 45.2
# episode:  139 score: 122.0 , average score 45.6
# episode:  140 score: 24.0 , average score 45.6
# episode:  141 score: 56.0 , average score 45.9
# episode:  142 score: 138.0 , average score 47.0
# episode:  143 score: 58.0 , average score 47.2
# episode:  144 score: 49.0 , average score 47.3
# episode:  145 score: 60.0 , average score 47.8
# episode:  146 score: 95.0 , average score 48.5
# episode:  147 score: 61.0 , average score 48.8
# episode:  148 score: 28.0 , average score 48.7
# episode:  149 score: 16.0 , average score 48.6
# episode:  150 score: 51.0 , average score 48.9
# episode:  151 score: 34.0 , average score 48.9
# episode:  152 score: 50.0 , average score 49.1
# episode:  153 score: 62.0 , average score 49.4
# episode:  154 score: 101.0 , average score 49.8
# episode:  155 score: 74.0 , average score 50.4
# episode:  156 score: 91.0 , average score 50.6
# episode:  157 score: 42.0 , average score 50.5
# episode:  158 score: 72.0 , average score 51.0
# episode:  159 score: 86.0 , average score 51.5
# episode:  160 score: 85.0 , average score 51.8
# episode:  161 score: 32.0 , average score 52.0
# episode:  162 score: 32.0 , average score 52.0
# episode:  163 score: 108.0 , average score 52.9
# episode:  164 score: 49.0 , average score 53.1
# episode:  165 score: 41.0 , average score 53.3
# episode:  166 score: 174.0 , average score 54.7
# episode:  167 score: 85.0 , average score 55.4
# episode:  168 score: 59.0 , average score 55.7
# episode:  169 score: 37.0 , average score 55.8
# episode:  170 score: 184.0 , average score 57.5
# episode:  171 score: 80.0 , average score 58.0
# episode:  172 score: 17.0 , average score 57.8
# episode:  173 score: 107.0 , average score 58.1
# episode:  174 score: 84.0 , average score 58.6
# episode:  175 score: 28.0 , average score 58.6
# episode:  176 score: 65.0 , average score 58.8
# episode:  177 score: 90.0 , average score 59.4
# episode:  178 score: 189.0 , average score 60.9
# episode:  179 score: 72.0 , average score 61.1
# episode:  180 score: 47.0 , average score 61.1
# episode:  181 score: 197.0 , average score 62.2
# episode:  182 score: 111.0 , average score 63.0
# episode:  183 score: 45.0 , average score 63.2
# episode:  184 score: 70.0 , average score 63.4
# episode:  185 score: 106.0 , average score 63.7
# episode:  186 score: 71.0 , average score 64.0
# episode:  187 score: 86.0 , average score 64.8
# episode:  188 score: 79.0 , average score 65.3
# episode:  189 score: 53.0 , average score 65.5
# episode:  190 score: 112.0 , average score 66.3
# episode:  191 score: 36.0 , average score 66.6
# episode:  192 score: 70.0 , average score 66.9
# episode:  193 score: 81.0 , average score 67.2
# episode:  194 score: 50.0 , average score 67.2
# episode:  195 score: 68.0 , average score 67.5
# episode:  196 score: 117.0 , average score 68.2
# episode:  197 score: 194.0 , average score 70.0
# episode:  198 score: 105.0 , average score 70.7
# episode:  199 score: 163.0 , average score 71.6
# data saved in file reinforce_v1_lr0010_g9900_runs8_eps300.csv
# episode:  200 score: 98.0 , average score 72.2
# episode:  201 score: 145.0 , average score 73.1
# episode:  202 score: 75.0 , average score 73.4
# episode:  203 score: 65.0 , average score 73.3
# episode:  204 score: 254.0 , average score 74.9
# episode:  205 score: 96.0 , average score 75.7
# episode:  206 score: 252.0 , average score 77.6
# episode:  207 score: 62.0 , average score 77.6
# episode:  208 score: 28.0 , average score 77.7
# episode:  209 score: 125.0 , average score 78.6
# episode:  210 score: 97.0 , average score 79.2
# episode:  211 score: 71.0 , average score 79.2
# episode:  212 score: 93.0 , average score 79.4
# episode:  213 score: 48.0 , average score 79.1
# episode:  214 score: 212.0 , average score 80.7
# episode:  215 score: 55.0 , average score 81.0
# episode:  216 score: 183.0 , average score 82.5
# episode:  217 score: 336.0 , average score 85.0
# episode:  218 score: 86.0 , average score 85.1
# episode:  219 score: 127.0 , average score 85.0
# episode:  220 score: 147.0 , average score 86.1
# episode:  221 score: 140.0 , average score 86.2
# episode:  222 score: 84.0 , average score 86.3
# episode:  223 score: 122.0 , average score 87.2
# episode:  224 score: 94.0 , average score 87.7
# episode:  225 score: 92.0 , average score 88.2
# episode:  226 score: 91.0 , average score 88.5
# episode:  227 score: 123.0 , average score 89.5
# episode:  228 score: 195.0 , average score 91.0
# episode:  229 score: 49.0 , average score 91.0
# episode:  230 score: 98.0 , average score 91.3
# episode:  231 score: 139.0 , average score 91.5
# episode:  232 score: 234.0 , average score 93.5
# episode:  233 score: 148.0 , average score 93.8
# episode:  234 score: 108.0 , average score 93.8
# episode:  235 score: 67.0 , average score 94.2
# episode:  236 score: 40.0 , average score 94.4
# episode:  237 score: 58.0 , average score 94.3
# episode:  238 score: 57.0 , average score 94.4
# episode:  239 score: 112.0 , average score 94.3
# episode:  240 score: 53.0 , average score 94.6
# episode:  241 score: 135.0 , average score 95.4
# episode:  242 score: 94.0 , average score 95.0
# episode:  243 score: 129.0 , average score 95.7
# episode:  244 score: 146.0 , average score 96.7
# episode:  245 score: 111.0 , average score 97.2
# episode:  246 score: 60.0 , average score 96.8
# episode:  247 score: 190.0 , average score 98.1
# episode:  248 score: 156.0 , average score 99.4
# episode:  249 score: 166.0 , average score 100.9
# episode:  250 score: 58.0 , average score 101.0
# episode:  251 score: 116.0 , average score 101.8
# episode:  252 score: 109.0 , average score 102.4
# episode:  253 score: 121.0 , average score 103.0
# episode:  254 score: 111.0 , average score 103.0
# episode:  255 score: 130.0 , average score 103.6
# episode:  256 score: 135.0 , average score 104.0
# episode:  257 score: 178.0 , average score 105.4
# episode:  258 score: 193.0 , average score 106.6
# episode:  259 score: 115.0 , average score 106.9
# episode:  260 score: 500.0 , average score 111.1
# episode:  261 score: 248.0 , average score 113.2
# episode:  262 score: 179.0 , average score 114.7
# episode:  263 score: 168.0 , average score 115.3
# episode:  264 score: 82.0 , average score 115.6
# episode:  265 score: 173.0 , average score 116.9
# episode:  266 score: 215.0 , average score 117.3
# episode:  267 score: 196.0 , average score 118.5
# episode:  268 score: 127.0 , average score 119.1
# episode:  269 score: 120.0 , average score 120.0
# episode:  270 score: 94.0 , average score 119.1
# episode:  271 score: 140.0 , average score 119.7
# episode:  272 score: 117.0 , average score 120.7
# episode:  273 score: 99.0 , average score 120.6
# episode:  274 score: 125.0 , average score 121.0
# episode:  275 score: 137.0 , average score 122.1
# episode:  276 score: 163.0 , average score 123.1
# episode:  277 score: 140.0 , average score 123.6
# episode:  278 score: 157.0 , average score 123.2
# episode:  279 score: 240.0 , average score 124.9
# episode:  280 score: 176.0 , average score 126.2
# episode:  281 score: 132.0 , average score 125.6
# episode:  282 score: 121.0 , average score 125.7
# episode:  283 score: 190.0 , average score 127.1
# episode:  284 score: 262.0 , average score 129.0
# episode:  285 score: 152.0 , average score 129.5
# episode:  286 score: 141.0 , average score 130.2
# episode:  287 score: 242.0 , average score 131.8
# episode:  288 score: 126.0 , average score 132.2
# episode:  289 score: 179.0 , average score 133.5
# episode:  290 score: 53.0 , average score 132.9
# episode:  291 score: 128.0 , average score 133.8
# episode:  292 score: 127.0 , average score 134.4
# episode:  293 score: 140.0 , average score 135.0
# episode:  294 score: 144.0 , average score 135.9
# episode:  295 score: 134.0 , average score 136.6
# episode:  296 score: 87.0 , average score 136.3
# episode:  297 score: 181.0 , average score 136.2
# episode:  298 score: 113.0 , average score 136.2
# episode:  299 score: 108.0 , average score 135.7
# data saved in file reinforce_v1_lr0010_g9900_runs8_eps300.csv
#
#
#
#
# beginning run number 1
# episode:  0 score: 20.0 , average score 20.0
# episode:  1 score: 21.0 , average score 20.5
# episode:  2 score: 22.0 , average score 21.0
# episode:  3 score: 11.0 , average score 18.5
# episode:  4 score: 36.0 , average score 22.0
# episode:  5 score: 13.0 , average score 20.5
# episode:  6 score: 33.0 , average score 22.3
# episode:  7 score: 46.0 , average score 25.2
# episode:  8 score: 24.0 , average score 25.1
# episode:  9 score: 12.0 , average score 23.8
# episode:  10 score: 31.0 , average score 24.5
# episode:  11 score: 33.0 , average score 25.2
# episode:  12 score: 37.0 , average score 26.1
# episode:  13 score: 26.0 , average score 26.1
# episode:  14 score: 20.0 , average score 25.7
# episode:  15 score: 27.0 , average score 25.8
# episode:  16 score: 29.0 , average score 25.9
# episode:  17 score: 31.0 , average score 26.2
# episode:  18 score: 16.0 , average score 25.7
# episode:  19 score: 37.0 , average score 26.2
# episode:  20 score: 12.0 , average score 25.6
# episode:  21 score: 39.0 , average score 26.2
# episode:  22 score: 15.0 , average score 25.7
# episode:  23 score: 35.0 , average score 26.1
# episode:  24 score: 15.0 , average score 25.6
# episode:  25 score: 24.0 , average score 25.6
# episode:  26 score: 28.0 , average score 25.7
# episode:  27 score: 33.0 , average score 25.9
# episode:  28 score: 16.0 , average score 25.6
# episode:  29 score: 29.0 , average score 25.7
# episode:  30 score: 44.0 , average score 26.3
# episode:  31 score: 35.0 , average score 26.6
# episode:  32 score: 36.0 , average score 26.8
# episode:  33 score: 18.0 , average score 26.6
# episode:  34 score: 54.0 , average score 27.4
# episode:  35 score: 32.0 , average score 27.5
# episode:  36 score: 56.0 , average score 28.3
# episode:  37 score: 31.0 , average score 28.3
# episode:  38 score: 15.0 , average score 28.0
# episode:  39 score: 27.0 , average score 28.0
# episode:  40 score: 41.0 , average score 28.3
# episode:  41 score: 37.0 , average score 28.5
# episode:  42 score: 14.0 , average score 28.2
# episode:  43 score: 41.0 , average score 28.5
# episode:  44 score: 29.0 , average score 28.5
# episode:  45 score: 18.0 , average score 28.2
# episode:  46 score: 41.0 , average score 28.5
# episode:  47 score: 47.0 , average score 28.9
# episode:  48 score: 20.0 , average score 28.7
# episode:  49 score: 40.0 , average score 28.9
# episode:  50 score: 31.0 , average score 29.0
# episode:  51 score: 57.0 , average score 29.5
# episode:  52 score: 48.0 , average score 29.9
# episode:  53 score: 25.0 , average score 29.8
# episode:  54 score: 36.0 , average score 29.9
# episode:  55 score: 32.0 , average score 29.9
# episode:  56 score: 95.0 , average score 31.1
# episode:  57 score: 76.0 , average score 31.8
# episode:  58 score: 98.0 , average score 33.0
# episode:  59 score: 71.0 , average score 33.6
# episode:  60 score: 79.0 , average score 34.3
# episode:  61 score: 82.0 , average score 35.1
# episode:  62 score: 83.0 , average score 35.9
# episode:  63 score: 47.0 , average score 36.0
# episode:  64 score: 139.0 , average score 37.6
# episode:  65 score: 55.0 , average score 37.9
# episode:  66 score: 32.0 , average score 37.8
# episode:  67 score: 60.0 , average score 38.1
# episode:  68 score: 69.0 , average score 38.6
# episode:  69 score: 23.0 , average score 38.4
# episode:  70 score: 71.0 , average score 38.8
# episode:  71 score: 33.0 , average score 38.7
# episode:  72 score: 48.0 , average score 38.9
# episode:  73 score: 36.0 , average score 38.8
# episode:  74 score: 29.0 , average score 38.7
# episode:  75 score: 32.0 , average score 38.6
# episode:  76 score: 100.0 , average score 39.4
# episode:  77 score: 74.0 , average score 39.8
# episode:  78 score: 63.0 , average score 40.1
# episode:  79 score: 27.0 , average score 40.0
# episode:  80 score: 56.0 , average score 40.2
# episode:  81 score: 220.0 , average score 42.4
# episode:  82 score: 44.0 , average score 42.4
# episode:  83 score: 104.0 , average score 43.1
# episode:  84 score: 40.0 , average score 43.1
# episode:  85 score: 63.0 , average score 43.3
# episode:  86 score: 24.0 , average score 43.1
# episode:  87 score: 95.0 , average score 43.7
# episode:  88 score: 141.0 , average score 44.8
# episode:  89 score: 78.0 , average score 45.1
# episode:  90 score: 57.0 , average score 45.3
# episode:  91 score: 106.0 , average score 45.9
# episode:  92 score: 67.0 , average score 46.2
# episode:  93 score: 152.0 , average score 47.3
# episode:  94 score: 80.0 , average score 47.6
# episode:  95 score: 98.0 , average score 48.2
# episode:  96 score: 62.0 , average score 48.3
# episode:  97 score: 39.0 , average score 48.2
# episode:  98 score: 62.0 , average score 48.3
# episode:  99 score: 114.0 , average score 49.0
# data saved in file reinforce_v1_lr0010_g9900_runs8_eps300.csv
# episode:  100 score: 86.0 , average score 49.7
# episode:  101 score: 38.0 , average score 49.8
# episode:  102 score: 50.0 , average score 50.1
# episode:  103 score: 61.0 , average score 50.6
# episode:  104 score: 152.0 , average score 51.8
# episode:  105 score: 116.0 , average score 52.8
# episode:  106 score: 79.0 , average score 53.3
# episode:  107 score: 55.0 , average score 53.4
# episode:  108 score: 23.0 , average score 53.3
# episode:  109 score: 115.0 , average score 54.4
# episode:  110 score: 46.0 , average score 54.5
# episode:  111 score: 113.0 , average score 55.3
# episode:  112 score: 34.0 , average score 55.3
# episode:  113 score: 200.0 , average score 57.0
# episode:  114 score: 78.0 , average score 57.6
# episode:  115 score: 95.0 , average score 58.3
# episode:  116 score: 160.0 , average score 59.6
# episode:  117 score: 154.0 , average score 60.8
# episode:  118 score: 142.0 , average score 62.1
# episode:  119 score: 81.0 , average score 62.5
# episode:  120 score: 85.0 , average score 63.3
# episode:  121 score: 137.0 , average score 64.2
# episode:  122 score: 88.0 , average score 65.0
# episode:  123 score: 119.0 , average score 65.8
# episode:  124 score: 70.0 , average score 66.4
# episode:  125 score: 32.0 , average score 66.4
# episode:  126 score: 60.0 , average score 66.8
# episode:  127 score: 93.0 , average score 67.4
# episode:  128 score: 58.0 , average score 67.8
# episode:  129 score: 135.0 , average score 68.8
# episode:  130 score: 80.0 , average score 69.2
# episode:  131 score: 169.0 , average score 70.5
# episode:  132 score: 127.0 , average score 71.5
# episode:  133 score: 31.0 , average score 71.6
# episode:  134 score: 211.0 , average score 73.2
# episode:  135 score: 114.0 , average score 74.0
# episode:  136 score: 88.0 , average score 74.3
# episode:  137 score: 117.0 , average score 75.2
# episode:  138 score: 118.0 , average score 76.2
# episode:  139 score: 90.0 , average score 76.8
# episode:  140 score: 101.0 , average score 77.4
# episode:  141 score: 151.0 , average score 78.5
# episode:  142 score: 172.0 , average score 80.1
# episode:  143 score: 51.0 , average score 80.2
# episode:  144 score: 138.0 , average score 81.3
# episode:  145 score: 122.0 , average score 82.4
# episode:  146 score: 89.0 , average score 82.8
# episode:  147 score: 176.0 , average score 84.1
# episode:  148 score: 173.0 , average score 85.7
# episode:  149 score: 62.0 , average score 85.9
# episode:  150 score: 140.0 , average score 87.0
# episode:  151 score: 225.0 , average score 88.7
# episode:  152 score: 66.0 , average score 88.8
# episode:  153 score: 100.0 , average score 89.6
# episode:  154 score: 125.0 , average score 90.5
# episode:  155 score: 140.0 , average score 91.5
# episode:  156 score: 85.0 , average score 91.5
# episode:  157 score: 135.0 , average score 92.0
# episode:  158 score: 83.0 , average score 91.9
# episode:  159 score: 88.0 , average score 92.1
# episode:  160 score: 104.0 , average score 92.3
# episode:  161 score: 252.0 , average score 94.0
# episode:  162 score: 153.0 , average score 94.7
# episode:  163 score: 101.0 , average score 95.2
# episode:  164 score: 409.0 , average score 98.0
# episode:  165 score: 118.0 , average score 98.6
# episode:  166 score: 138.0 , average score 99.6
# episode:  167 score: 67.0 , average score 99.7
# episode:  168 score: 231.0 , average score 101.3
# episode:  169 score: 126.0 , average score 102.4
# episode:  170 score: 104.0 , average score 102.7
# episode:  171 score: 204.0 , average score 104.4
# episode:  172 score: 218.0 , average score 106.1
# episode:  173 score: 150.0 , average score 107.2
# episode:  174 score: 80.0 , average score 107.8
# episode:  175 score: 247.0 , average score 109.9
