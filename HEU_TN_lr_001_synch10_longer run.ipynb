# %%
import gym
import tensorflow as tf
from collections import deque
import numpy as np
from random import sample, randint
from tensorflow import keras
# from Helper import argmax, softmax
import matplotlib.pyplot as plt
from keras.utils.np_utils import to_categorical

# %%
def softmax(x, temp):
    ''' Computes the softmax of vector x with temperature parameter 'temp' '''
    x = x / temp # scale by temperature
    z = x - max(x) # substract max to prevent overflow of softmax 
    return np.exp(z)/np.sum(np.exp(z)) # compute softmax

def argmax(x):
    ''' Own variant of np.argmax with random tie breaking '''
    try:
        return np.random.choice(np.where(x == np.max(x))[0])
    except:
        return np.argmax(x)

# %%
def get_model(ip_shape,lr,op_shape,summary = True):
    '''
    get_model(ip_shape,lr,op_shape,summary = True):
    creates and returns a model and prints it's summary based on summary flag
    '''
    
    model = keras.models.Sequential()
    model.add(keras.layers.Flatten(input_shape=ip_shape))
    model.add(keras.layers.Dense(24, kernel_initializer = tf.keras.initializers.HeUniform(seed=None), activation="relu"))
    model.add(keras.layers.Dense(24, kernel_initializer = tf.keras.initializers.HeUniform(seed=None), activation="relu"))
    model.add(keras.layers.Dense(24, kernel_initializer = tf.keras.initializers.HeUniform(seed=None), activation="relu"))
    model.add(keras.layers.Dense(op_shape, activation="linear"))

    # compile model
    model.compile(loss="mean_squared_error",optimizer=keras.optimizers.Adam(learning_rate=lr),metrics=["accuracy"])
    if summary == True:
        print(model.summary())
    return(model)

class experience_deque:
    '''
    __init__(self, max_len):
    
    # methods:
    add_experience(self,s,a,r,s_next,done):
    get_batch(self, batch_size):
    '''
    def __init__(self, max_len):
        '''initialisation'''
        #initialise max buffer length
        self.deque_size = max_len
        
        # initialise buffer for live deque length
        self.live_ds = 0
        
        # initialise experience buffers
        self.s_experience = deque(maxlen = self.deque_size)
        self.s_next_experience = deque(maxlen = self.deque_size)
        self.a_experience = deque(maxlen = self.deque_size)
        self.r_experience = deque(maxlen = self.deque_size)
        self.d_experience = deque(maxlen = self.deque_size)
        
        
        
        
    def add_experience(self,s,a,r,s_next,done):
        '''
        add_experience(self,s,a,r,s_next,done)
        add an experience to the deques
        '''
        self.s_experience.append(s)
        self.s_next_experience.append(s_next)
        self.a_experience.append(a)
        self.r_experience.append(r)
        self.d_experience.append(done)
        
        #update live deque size
        self.live_ds = len(self.s_experience)
        
        

        
        
    def get_batch(self, batch_size):
        '''
        get_batch(self, batch_size):
        generate random samples from experiences
        returns them
        '''
        # warn that deque is not full
        if self.live_ds < self.deque_size:
            if self.live_ds%1000 == 0:
                print(self.live_ds)
                
#             print("deque is not full, current size is : ", self.live_ds)
#             if batch_size > self.live_ds:
#                 print("batch size bigger than live deque size (bs,lds): ", batch_size, self.live_ds)
#             else:
#                 print("sampling from incomplete deque (bs,lds): ", batch_size, self.live_ds)
        
        # get random indices
        ind = sample(range(self.live_ds), batch_size)
        
        # sample from all deques
        s_sampled = np.asarray(self.s_experience)[ind]
        s_next_sampled = np.asarray(self.s_next_experience)[ind]
        a_sampled = np.asarray(self.a_experience)[ind]
        r_sampled = np.asarray(self.r_experience)[ind]
        d_sampled = np.asarray(self.d_experience)[ind]
        
        return (s_sampled,s_next_sampled,a_sampled,r_sampled,d_sampled)
        

class DQNagent:
    '''
    __init__(self, n_states, n_actions, learning_rate, gamma, max_len,
    er = True, tn = True, conv = False, summary = True, verbose = 0):
    Sets up a model and provides handy methods to interact with it
    '''
    
    def __init__(self, env, buffer, live_model, gamma, target_model, er = True,
                 TN = True, summary = True, verbose = 2, ):
        '''Iniitialization function for class DQNagent, read the __docs__'''
        
        # used for 
        self.TN = TN
        self.buffer = buffer
        self.live_model = live_model
        if TN:
            self.target_model = target_model
        self.n_states = env.observation_space.shape
        self.n_actions = env.action_space.n
        self.gamma = gamma
#         self.deque_size = max_len
        self.verbose = verbose


        
        
    def select_action(self, state, policy='egreedy', epsilon=None, temp=None):
        '''
        select_action(self, s, policy='egreedy', epsilon=None, temp=None):
        selects action based on policy specified
        returns action
        '''
        state = state.reshape(1,4)
        if policy == 'egreedy':
            if epsilon is None:
                raise KeyError("Provide an epsilon")
                
            # TO DO: Add own code
            exploit = np.random.choice([0,1],p = [epsilon,1-epsilon])
            if exploit:
#                 print(q[0])
                a = argmax((self.live_model.predict(state))[0])
#                 print("exploiting: ",a)
            else:
                a = np.random.randint(0,self.n_actions) # Replace this with correct action selection
#                 print("exploring: ",a)
                
#         elif policy == 'softmax':
#             if temp is None:
#                 raise KeyError("Provide a temperature")
                
#             # TO DO: Add own code
#             a = np.random.randint(0,self.n_actions) # Replace this with correct action selection
#             print("action selected :", a)
        return a
                

    '''
    
     Cited in the report, used for inspiration
     
     
    def update(self,s,a,r,s_next,done):
        #perform a Q-learning update

        # TO DO: Add own code
        G = r + ( self.gamma * np.max(self.Q_sa[s_next,:]) )
        self.Q_sa[s,a] = self.Q_sa[s,a] + ( self.learning_rate * ( G - self.Q_sa[s,a] ) )
        pass
    
#                     def fit_batch(env, model, target_model, batch):
#                        observations, actions, rewards, next_observations, dones = batch
#                        # Predict the Q values of the next states. Passing ones as the action mask.
#                        next_q_values = predict(env, target_model, next_observations)
#                        # The Q values of terminal states is 0 by definition.
#                        next_q_values[dones] = 0.0
#                        # The Q values of each start state is the reward + gamma * the max next state Q value
#                        q_values = rewards + DISCOUNT_FACTOR_GAMMA * np.max(next_q_values, axis=1)
#                        one_hot_actions = np.array([one_hot_encode(env.action_space.n, action) for action in actions])
#                        history = model.fit(
#                            x=[observations, one_hot_actions],
#                            y=one_hot_actions * q_values[:, None],
#                            batch_size=BATCH_SIZE,
#                            verbose=0,
#                        )
#                        return history.history['loss'][0]

    '''
    
    def update_er_tn(self,batch_of_ss, batch_of_as, batch_of_sns, batch_of_rs,batch_of_ds, batch_size):
        '''
        update_er_tn(self,batch):
        perform a Q-learning update
        '''
        if not self.TN:
            print("wrong call")

        # get target Q values for the batch
        q_next_batch = self.target_model.predict(batch_of_sns)
        
        # calculate targets and assign done rewards
        G1 = self.live_model.predict(batch_of_ss)
        cat_boa = to_categorical(batch_of_as,num_classes = 2)
        cat_inv_boa = to_categorical(np.invert(batch_of_as),num_classes = 2)
        G1 = G1 * cat_inv_boa
        G2 = batch_of_rs + ( self.gamma * np.max(q_next_batch, axis = 1) )
        G2 = np.where(batch_of_ds == True, batch_of_rs, G2)
        G2 = G2.reshape(G2.shape[0],1)
        G2 = G2 * cat_boa
        G_batch = G1+G2

        
        # update live_network
        history = self.live_model.fit(batch_of_ss,G_batch, batch_size = batch_size, verbose = 0)
        
        return history
    
    def update_er(self,batch_of_ss, batch_of_as, batch_of_sns, batch_of_rs,batch_of_ds, batch_size):
        '''
        update_er(self,batch):
        perform a Q-learning update
        '''
        if self.TN:
            print("wrong call")
        # get target Q values for the batch
        q_next_batch = self.live_model.predict(batch_of_sns)
        
        # calculate targets and assign done rewards
        G1 = self.live_model.predict(batch_of_ss)
        cat_boa = to_categorical(batch_of_as,num_classes = 2)
        cat_inv_boa = to_categorical(np.invert(batch_of_as),num_classes = 2)
        G1 = G1 * cat_inv_boa
        G2 = batch_of_rs + ( self.gamma * np.max(q_next_batch, axis = 1) )
        G2 = np.where(batch_of_ds == True, batch_of_rs, G2)
        G2 = G2.reshape(G2.shape[0],1)
        G2 = G2 * cat_boa
        G_batch = G1+G2

        
        # update live_network
        history = self.live_model.fit(batch_of_ss,G_batch, batch_size = batch_size, verbose = 0)
        
        return history
    
    
    
    
    def synch_weights(self):
        '''
        synch_weights(self):
        synchronises target model weights
        '''
        self.target_model.set_weights(self.live_model.get_weights())
        print("weights synched")

def decay_eps(epsilon = 1, min_epsilon = 0.01, decay_rate = 0.95):
    '''
    decay_eps(max_epsilon = 1, min_epsilon = 0.01, decay_rate = 0.995):
    decay the epsilon value
    '''
#     if epsilon<0.2:
#         decay_rate = 0.995
    epsilon *= decay_rate
    return max(epsilon, min_epsilon)

# main loop for a single run, averaging loop is not included
def Qlearn(learning_rate, epsilon, buffer_size, n_eps, max_timesteps,min_batch_size, synch_weight_freq, decay_epsilon = True, TN = True):
    
    # initialise environment
    env = gym.make('CartPole-v1')
    
    # create buffers for kpi
    cum_reward_per_ep = [] # list of final rewards [n_eps]

    # initialise networks
    live_net = get_model(env.observation_space.shape,learning_rate,env.action_space.n)
    
    if TN:
        target_net = get_model(env.observation_space.shape,learning_rate,env.action_space.n)
    
    # initialise buffers
    buffer = experience_deque(max_len = buffer_size)
    
    # initialise agent
#         def __init__(self, env, buffer, live_model, target_model,  gamma, batch_size, er = True,
#                  tn = True, summary = True, verbose = 2):
    if TN:
        agent = DQNagent(env, buffer, live_net, gamma, target_model = target_net, TN = TN)
    else:
        agent = DQNagent(env, buffer, live_net, gamma, target_model = None, TN = TN)
    
    # count for target net update
    step_count = 0
    
    # loop over eps
    for ep_num in range(n_eps):
        print("staring ep: ", ep_num)
        s = env.reset()
        rewards = []
        cum_reward = 0
        ep_list = []
        
#         if ep_num == 24:
#                 print ("\n\n\n\n\n\n training interval changed to 100 steps \n\n\n\n\n\n")
#                 synch_weight_freq = 100
#         if ep_num == 50:
#                 print ("\n\n\n\n\n\n training interval changed to 1000 steps \n\n\n\n\n\n")
#                 synch_weight_freq = 1000
        
        # loop over timesteps
        for step in range(max_timesteps):
            
                
            step_count += 1
#             env.render()
            
            # select action
            a = agent.select_action(state = s,policy = 'egreedy', epsilon = epsilon)

            
            # play a step
            s_next,reward,done,_ = env.step(a)
            cum_reward += reward
            
            # save experience
            buffer.add_experience(s,a,reward,s_next,done)
            
            calc_batch_size = min(int(0.7*buffer.live_ds),500)
        
            if buffer.live_ds >= min_batch_size:
#                 print("buffer min reached")
#             if step = 500
                
                # get batch from memory
                s_exp_batch,s_next_exp_batch,a_exp_batch,r_exp_batch,d_exp_batch = buffer.get_batch(calc_batch_size)

                # run a DQN training loop
                if TN:
#                     print("TN training")
                    history = agent.update_er_tn(s_exp_batch,a_exp_batch,s_next_exp_batch,r_exp_batch,d_exp_batch,calc_batch_size)
#                     print("loss = ",history.history["loss"][0])
                else:
#                     print("training")
                    history = agent.update_er(s_exp_batch,a_exp_batch,s_next_exp_batch,r_exp_batch,d_exp_batch,calc_batch_size)
                    #                 print("loss = ",history.history["loss"][0])
                if TN:
                    # copy weights to target_network
                    if step_count%synch_weight_freq == 0:
                        agent.synch_weights()



            # check if done
            if done:
#                 print("done = ",done)
                print("ep = ", ep_num, "    epsilon = ", epsilon, "    steps = ", step,"    ep reward = ",cum_reward)
                break
                
                
        
            # set new state
            s = s_next
#             print(step)
            
            
            # timestep loop ends
                        
            
        # end of episode calculations
        
        # collect kpi
        cum_reward_per_ep.append(cum_reward)
        
        
        # Decay probability of taking random action
        if decay_epsilon:
            epsilon = decay_eps(epsilon,eps_min)
            
        
        # check if done
        if ep_num>benchmark_averaging_eps:
            avg_10ep_cum_rewards = np.mean(cum_reward_per_ep[-benchmark_averaging_eps:])
            print("avg 20 ep rewards : ",avg_10ep_cum_rewards)
#             if avg_10ep_cum_rewards >= benchmark:
#                 print("\n\n\n Rewards have converged to a value above the benchmark score (",benchmark,") \n\n\n")
#                 break
                
#                 extend = input('another episode? (y/n)')
#                 if extend == 'y':
#                     continue
#                 else:
#                     break
                    
        ep_list.append(ep_num)
                
    return (cum_reward_per_ep, avg_10ep_cum_rewards, ep_list)
    



def safe(fname = "TN_heu_lr001_synch10.csv"):
    try:
        fig = plt.figure(figsize = (14,7))
        list_y = []
        for i,y in enumerate(cum_rewards):
            y = np.array(y)
            y = np.pad(y,(0,300-y.shape[0]),mode = 'constant',constant_values = (np.nan))
            list_y.append(y)
            np.savetxt(fname, list_y, delimiter = "," )
    #         print(y.shape)
            plt.plot(range(y.shape[0]),y,label = r"run "+str(i+1))
        plt.title("TN individual")
        plt.xlabel("Rewards")
        plt.ylabel("Episodes")
        list_y = np.array(list_y)
        print(list_y.shape)
        fig = plt.figure(figsize = (14,7))
        plt.plot(range(300), np.nanmean(list_y, axis = 0))
        plt.xlabel("Rewards")
        plt.ylabel("Episodes")
        plt.title("TN individual")
    except Exception as e:
        print(e)

# %%
n_eps = 100                  # max number of eps
buffer_size = 10000
synch_weight_freq = 10
learning_rate = 0.001
gamma = 0.995                 # discount factor
epsilon = 1
min_batch_size = 32              # size of the replay sample
# min_buff = 1000
max_timesteps = 500           # max steps an episode can last
eps_min = 0.01
num_runs = 10
benchmark_averaging_eps = 20  # how many eps to average over to compare benchmark
benchmark = 350

# %%
# physical_devices = tf.config.list_physical_devices('GPU')
# tf.config.experimental.set_memory_growth(physical_devices[0], enable=True)
# print(physical_devices)

# buffers for kpis
cum_rewards = []
averages_at_end = []
list_of_ep_nums = []

# loop for averaging over 8 runs
for run in range(num_runs):
#     learning_rate, epsilon, buffer_size, n_eps, max_timesteps,min_batch_size
    cum_rewards_run, averages_at_end_run, list_of_ep_nums = Qlearn(learning_rate, epsilon, buffer_size,
                                                                   n_eps, max_timesteps, min_batch_size, synch_weight_freq,
                                                                   TN = True)
    cum_rewards.append(cum_rewards_run)
    averages_at_end.append(averages_at_end_run)
    list_of_ep_nums.append(run)
    safe()

# summarise results
print(np.shape(cum_rewards))
print(np.shape(averages_at_end))
# Out:
# Model: "sequential_14"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_14 (Flatten)        (None, 4)                 0
#
#  dense_56 (Dense)            (None, 24)                120
#
#  dense_57 (Dense)            (None, 24)                600
#
#  dense_58 (Dense)            (None, 24)                600
#
#  dense_59 (Dense)            (None, 2)                 50
#
# =================================================================
# Total params: 1,370
# Trainable params: 1,370
# Non-trainable params: 0
# _________________________________________________________________
# None
# Model: "sequential_15"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_15 (Flatten)        (None, 4)                 0
#
#  dense_60 (Dense)            (None, 24)                120
#
#  dense_61 (Dense)            (None, 24)                600
#
#  dense_62 (Dense)            (None, 24)                600
#
#  dense_63 (Dense)            (None, 2)                 50
#
# =================================================================
# Total params: 1,370
# Trainable params: 1,370
# Non-trainable params: 0
# _________________________________________________________________
# None
# staring ep:  0
# ep =  0     epsilon =  1     steps =  23     ep reward =  24.0
# staring ep:  1
# weights synched
# ep =  1     epsilon =  0.95     steps =  24     ep reward =  25.0
# staring ep:  2
# weights synched
# weights synched
# ep =  2     epsilon =  0.9025     steps =  15     ep reward =  16.0
# staring ep:  3
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# ep =  3     epsilon =  0.8573749999999999     steps =  70     ep reward =  71.0
# staring ep:  4
# weights synched
# weights synched
# ep =  4     epsilon =  0.8145062499999999     steps =  14     ep reward =  15.0
# staring ep:  5
# weights synched
# ep =  5     epsilon =  0.7737809374999999     steps =  12     ep reward =  13.0
# staring ep:  6
# weights synched
# ep =  6     epsilon =  0.7350918906249998     steps =  9     ep reward =  10.0
# staring ep:  7
# weights synched
# ep =  7     epsilon =  0.6983372960937497     steps =  12     ep reward =  13.0
# staring ep:  8
# weights synched
# ep =  8     epsilon =  0.6634204312890623     steps =  10     ep reward =  11.0
# staring ep:  9
# weights synched
# weights synched
# ep =  9     epsilon =  0.6302494097246091     steps =  14     ep reward =  15.0
# staring ep:  10
# weights synched
# ep =  10     epsilon =  0.5987369392383786     steps =  11     ep reward =  12.0
# staring ep:  11
# weights synched
# ep =  11     epsilon =  0.5688000922764596     steps =  10     ep reward =  11.0
# staring ep:  12
# weights synched
# ep =  12     epsilon =  0.5403600876626365     steps =  9     ep reward =  10.0
# staring ep:  13
# weights synched
# ep =  13     epsilon =  0.5133420832795047     steps =  10     ep reward =  11.0
# staring ep:  14
# weights synched
# ep =  14     epsilon =  0.48767497911552943     steps =  9     ep reward =  10.0
# staring ep:  15
# weights synched
# weights synched
# weights synched
# weights synched
# ep =  15     epsilon =  0.46329123015975293     steps =  39     ep reward =  40.0
# staring ep:  16
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# ep =  16     epsilon =  0.44012666865176525     steps =  53     ep reward =  54.0
# staring ep:  17
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# ep =  17     epsilon =  0.41812033521917696     steps =  68     ep reward =  69.0
# staring ep:  18
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# ep =  18     epsilon =  0.3972143184582181     steps =  127     ep reward =  128.0
# staring ep:  19
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# ep =  19     epsilon =  0.37735360253530714     steps =  72     ep reward =  73.0
# staring ep:  20
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# ep =  20     epsilon =  0.35848592240854177     steps =  234     ep reward =  235.0
# staring ep:  21
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# ep =  21     epsilon =  0.34056162628811465     steps =  59     ep reward =  60.0
# avg 20 ep rewards :  43.85
# staring ep:  22
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# 1000
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# ep =  22     epsilon =  0.3235335449737089     steps =  181     ep reward =  182.0
# avg 20 ep rewards :  52.15
# staring ep:  23
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# ep =  23     epsilon =  0.30735686772502346     steps =  136     ep reward =  137.0
# avg 20 ep rewards :  55.45
# staring ep:  24
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# ep =  24     epsilon =  0.2919890243387723     steps =  147     ep reward =  148.0
# avg 20 ep rewards :  62.1
# staring ep:  25
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# ep =  25     epsilon =  0.27738957312183365     steps =  230     ep reward =  231.0
# avg 20 ep rewards :  73.0
# staring ep:  26
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# ep =  26     epsilon =  0.263520094465742     steps =  275     ep reward =  276.0
# avg 20 ep rewards :  86.3
# staring ep:  27
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# 2000
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# ep =  27     epsilon =  0.25034408974245487     steps =  242     ep reward =  243.0
# avg 20 ep rewards :  97.8
# staring ep:  28
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# ep =  28     epsilon =  0.2378268852553321     steps =  263     ep reward =  264.0
# avg 20 ep rewards :  110.45
# staring ep:  29
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# ep =  29     epsilon =  0.2259355409925655     steps =  112     ep reward =  113.0
# avg 20 ep rewards :  115.35
# staring ep:  30
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# ep =  30     epsilon =  0.2146387639429372     steps =  207     ep reward =  208.0
# avg 20 ep rewards :  125.15
# staring ep:  31
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# ep =  31     epsilon =  0.20390682574579033     steps =  217     ep reward =  218.0
# avg 20 ep rewards :  135.5
# staring ep:  32
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# 3000
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# ep =  32     epsilon =  0.1937114844585008     steps =  311     ep reward =  312.0
# avg 20 ep rewards :  150.6
# staring ep:  33
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# ep =  33     epsilon =  0.18402591023557577     steps =  177     ep reward =  178.0
# avg 20 ep rewards :  158.95
# staring ep:  34
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# ep =  34     epsilon =  0.17482461472379698     steps =  374     ep reward =  375.0
# avg 20 ep rewards :  177.2
# staring ep:  35
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# 4000
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# ep =  35     epsilon =  0.16608338398760714     steps =  308     ep reward =  309.0
# avg 20 ep rewards :  190.65
# staring ep:  36
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# ep =  36     epsilon =  0.15777921478822676     steps =  177     ep reward =  178.0
# avg 20 ep rewards :  196.85
# staring ep:  37
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# ep =  37     epsilon =  0.14989025404881542     steps =  219     ep reward =  220.0
# avg 20 ep rewards :  204.4
# staring ep:  38
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# ep =  38     epsilon =  0.14239574134637464     steps =  352     ep reward =  353.0
# avg 20 ep rewards :  215.65
# staring ep:  39
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# 5000
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# ep =  39     epsilon =  0.1352759542790559     steps =  291     ep reward =  292.0
# avg 20 ep rewards :  226.6
# staring ep:  40
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# ep =  40     epsilon =  0.1285121565651031     steps =  276     ep reward =  277.0
# avg 20 ep rewards :  228.7
# staring ep:  41
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# ep =  41     epsilon =  0.12208654873684793     steps =  298     ep reward =  299.0
# avg 20 ep rewards :  240.65
# staring ep:  42
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# 6000
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# ep =  42     epsilon =  0.11598222130000553     steps =  301     ep reward =  302.0
# avg 20 ep rewards :  246.65
# staring ep:  43
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# ep =  43     epsilon =  0.11018311023500525     steps =  311     ep reward =  312.0
# avg 20 ep rewards :  255.4
# staring ep:  44
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# ep =  44     epsilon =  0.10467395472325498     steps =  389     ep reward =  390.0
# avg 20 ep rewards :  267.5
# staring ep:  45
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# 7000
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# ep =  45     epsilon =  0.09944025698709223     steps =  434     ep reward =  435.0
# avg 20 ep rewards :  277.7
# staring ep:  46
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# ep =  46     epsilon =  0.09446824413773762     steps =  368     ep reward =  369.0
# avg 20 ep rewards :  282.35
# staring ep:  47
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# ep =  47     epsilon =  0.08974483193085074     steps =  308     ep reward =  309.0
# avg 20 ep rewards :  285.65
# staring ep:  48
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# 8000
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# ep =  48     epsilon =  0.0852575903343082     steps =  499     ep reward =  500.0
# avg 20 ep rewards :  297.45
# staring ep:  49
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# ep =  49     epsilon =  0.08099471081759278     steps =  499     ep reward =  500.0
# avg 20 ep rewards :  316.8
# staring ep:  50
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# 9000
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# ep =  50     epsilon =  0.07694497527671314     steps =  230     ep reward =  231.0
# avg 20 ep rewards :  317.95
# staring ep:  51
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# ep =  51     epsilon =  0.07309772651287748     steps =  238     ep reward =  239.0
# avg 20 ep rewards :  319.0
# staring ep:  52
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# ep =  52     epsilon =  0.0694428401872336     steps =  185     ep reward =  186.0
# avg 20 ep rewards :  312.7
# staring ep:  53
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# ep =  53     epsilon =  0.0659706981778719     steps =  176     ep reward =  177.0
# avg 20 ep rewards :  312.65
# staring ep:  54
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# ep =  54     epsilon =  0.0626721632689783     steps =  279     ep reward =  280.0
# avg 20 ep rewards :  307.9
# staring ep:  55
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# ep =  55     epsilon =  0.059538555105529384     steps =  184     ep reward =  185.0
# avg 20 ep rewards :  301.7
# staring ep:  56
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# ep =  56     epsilon =  0.05656162735025291     steps =  303     ep reward =  304.0
# avg 20 ep rewards :  308.0
# staring ep:  57
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# ep =  57     epsilon =  0.053733545982740265     steps =  499     ep reward =  500.0
# avg 20 ep rewards :  322.0
# staring ep:  58
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# ep =  58     epsilon =  0.05104686868360325     steps =  299     ep reward =  300.0
# avg 20 ep rewards :  319.35
# staring ep:  59
# weights synched
# weights synched
# weights synched
# ep =  59     epsilon =  0.04849452524942309     steps =  21     ep reward =  22.0
# avg 20 ep rewards :  305.85
# staring ep:  60
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# ep =  60     epsilon =  0.04606979898695193     steps =  97     ep reward =  98.0
# avg 20 ep rewards :  296.9
# staring ep:  61
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# ep =  61     epsilon =  0.04376630903760433     steps =  499     ep reward =  500.0
# avg 20 ep rewards :  306.95
# staring ep:  62
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# ep =  62     epsilon =  0.041577993585724116     steps =  499     ep reward =  500.0
# avg 20 ep rewards :  316.85
# staring ep:  63
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# ep =  63     epsilon =  0.03949909390643791     steps =  485     ep reward =  486.0
# avg 20 ep rewards :  325.55
# staring ep:  64
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# ep =  64     epsilon =  0.03752413921111601     steps =  499     ep reward =  500.0
# avg 20 ep rewards :  331.05
# staring ep:  65
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# ep =  65     epsilon =  0.03564793225056021     steps =  499     ep reward =  500.0
# avg 20 ep rewards :  334.3
# staring ep:  66
# weights synched
# ep =  66     epsilon =  0.0338655356380322     steps =  10     ep reward =  11.0
# avg 20 ep rewards :  316.4
# staring ep:  67
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# ep =  67     epsilon =  0.032172258856130585     steps =  465     ep reward =  466.0
# avg 20 ep rewards :  324.25
# staring ep:  68
# weights synched
# ep =  68     epsilon =  0.030563645913324056     steps =  12     ep reward =  13.0
# avg 20 ep rewards :  299.9
# staring ep:  69
# weights synched
# weights synched
# ep =  69     epsilon =  0.029035463617657853     steps =  24     ep reward =  25.0
# avg 20 ep rewards :  276.15
# staring ep:  70
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# ep =  70     epsilon =  0.027583690436774957     steps =  394     ep reward =  395.0
# avg 20 ep rewards :  284.35
# staring ep:  71
# weights synched
# ep =  71     epsilon =  0.02620450591493621     steps =  9     ep reward =  10.0
# avg 20 ep rewards :  272.9
# staring ep:  72
# weights synched
# ep =  72     epsilon =  0.0248942806191894     steps =  9     ep reward =  10.0
# avg 20 ep rewards :  264.1
# staring ep:  73
# weights synched
# ep =  73     epsilon =  0.023649566588229927     steps =  9     ep reward =  10.0
# avg 20 ep rewards :  255.75
# staring ep:  74
# weights synched
# ep =  74     epsilon =  0.022467088258818428     steps =  10     ep reward =  11.0
# avg 20 ep rewards :  242.3
# staring ep:  75
# weights synched
# ep =  75     epsilon =  0.021343733845877507     steps =  11     ep reward =  12.0
# avg 20 ep rewards :  233.65
# staring ep:  76
# weights synched
# weights synched
# weights synched
# weights synched
# ep =  76     epsilon =  0.02027654715358363     steps =  32     ep reward =  33.0
# avg 20 ep rewards :  220.1
# staring ep:  77
# weights synched
# weights synched
# weights synched
# ep =  77     epsilon =  0.019262719795904448     steps =  30     ep reward =  31.0
# avg 20 ep rewards :  196.65
# staring ep:  78
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# ep =  78     epsilon =  0.018299583806109226     steps =  431     ep reward =  432.0
# avg 20 ep rewards :  203.25
# staring ep:  79
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# ep =  79     epsilon =  0.017384604615803764     steps =  499     ep reward =  500.0
# avg 20 ep rewards :  227.15
# staring ep:  80
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# ep =  80     epsilon =  0.016515374385013576     steps =  499     ep reward =  500.0
# avg 20 ep rewards :  247.25
# staring ep:  81
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# ep =  81     epsilon =  0.015689605665762895     steps =  499     ep reward =  500.0
# avg 20 ep rewards :  247.25
# staring ep:  82
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# ep =  82     epsilon =  0.01490512538247475     steps =  499     ep reward =  500.0
# avg 20 ep rewards :  247.25
# staring ep:  83
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# ep =  83     epsilon =  0.014159869113351011     steps =  499     ep reward =  500.0
# avg 20 ep rewards :  247.95
# staring ep:  84
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# ep =  84     epsilon =  0.01345187565768346     steps =  499     ep reward =  500.0
# avg 20 ep rewards :  247.95
# staring ep:  85
# weights synched
# ep =  85     epsilon =  0.012779281874799287     steps =  7     ep reward =  8.0
# avg 20 ep rewards :  223.35
# staring ep:  86
# weights synched
# ep =  86     epsilon =  0.012140317781059323     steps =  9     ep reward =  10.0
# avg 20 ep rewards :  223.3
# staring ep:  87
# weights synched
# ep =  87     epsilon =  0.011533301892006355     steps =  9     ep reward =  10.0
# avg 20 ep rewards :  200.5
# staring ep:  88
# weights synched
# ep =  88     epsilon =  0.010956636797406038     steps =  8     ep reward =  9.0
# avg 20 ep rewards :  200.3
# staring ep:  89
# weights synched
# ep =  89     epsilon =  0.010408804957535735     steps =  9     ep reward =  10.0
# avg 20 ep rewards :  199.55
# staring ep:  90
# ep =  90     epsilon =  0.01     steps =  8     ep reward =  9.0
# avg 20 ep rewards :  180.25
# staring ep:  91
# weights synched
# ep =  91     epsilon =  0.01     steps =  9     ep reward =  10.0
# avg 20 ep rewards :  180.25
# staring ep:  92
# weights synched
# ep =  92     epsilon =  0.01     steps =  9     ep reward =  10.0
# avg 20 ep rewards :  180.25
# staring ep:  93
# weights synched
# ep =  93     epsilon =  0.01     steps =  9     ep reward =  10.0
# avg 20 ep rewards :  180.25
# staring ep:  94
# weights synched
# ep =  94     epsilon =  0.01     steps =  9     ep reward =  10.0
# avg 20 ep rewards :  180.2
# staring ep:  95
# weights synched
# ep =  95     epsilon =  0.01     steps =  9     ep reward =  10.0
# avg 20 ep rewards :  180.1
# staring ep:  96
# weights synched
# ep =  96     epsilon =  0.01     steps =  9     ep reward =  10.0
# avg 20 ep rewards :  178.95
# staring ep:  97
# weights synched
# weights synched
# ep =  97     epsilon =  0.01     steps =  12     ep reward =  13.0
# avg 20 ep rewards :  178.05
# staring ep:  98
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# ep =  98     epsilon =  0.01     steps =  499     ep reward =  500.0
# avg 20 ep rewards :  181.45
# staring ep:  99
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# ep =  99     epsilon =  0.01     steps =  499     ep reward =  500.0
# avg 20 ep rewards :  181.45
# (1, 300)
# Model: "sequential_16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_16 (Flatten)        (None, 4)                 0
#
#  dense_64 (Dense)            (None, 24)                120
#
#  dense_65 (Dense)            (None, 24)                600
#
#  dense_66 (Dense)            (None, 24)                600
#
#  dense_67 (Dense)            (None, 2)                 50
#
# =================================================================
# Total params: 1,370
# Trainable params: 1,370
# Non-trainable params: 0
# _________________________________________________________________
# None
# Model: "sequential_17"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_17 (Flatten)        (None, 4)                 0
#
#  dense_68 (Dense)            (None, 24)                120
#
#  dense_69 (Dense)            (None, 24)                600
#
#  dense_70 (Dense)            (None, 24)                600
#
#  dense_71 (Dense)            (None, 2)                 50
#
# =================================================================
# Total params: 1,370
# Trainable params: 1,370
# Non-trainable params: 0
# _________________________________________________________________
# None
# staring ep:  0
# ep =  0     epsilon =  1     steps =  15     ep reward =  16.0
# staring ep:  1
# C:\Users\ambar\AppData\Local\Temp\ipykernel_6132\1537216934.py:411: RuntimeWarning: Mean of empty slice
#   plt.plot(range(300), np.nanmean(list_y, axis = 0))
# weights synched
# weights synched
# weights synched
# ep =  1     epsilon =  0.95     steps =  49     ep reward =  50.0
# staring ep:  2
# weights synched
# weights synched
# ep =  2     epsilon =  0.9025     steps =  17     ep reward =  18.0
# staring ep:  3
# weights synched
# ep =  3     epsilon =  0.8573749999999999     steps =  11     ep reward =  12.0
# staring ep:  4
# weights synched
# weights synched
# weights synched
# weights synched
# ...
# weights synched
# weights synched
# weights synched
# weights synched
# ep =  68     epsilon =  0.030563645913324056     steps =  499     ep reward =  500.0
# avg 20 ep rewards :  377.8
# staring ep:  69
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# ep =  69     epsilon =  0.029035463617657853     steps =  499     ep reward =  500.0
# avg 20 ep rewards :  391.1
# staring ep:  70
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# ep =  70     epsilon =  0.027583690436774957     steps =  499     ep reward =  500.0
# avg 20 ep rewards :  399.5
# staring ep:  71
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# ep =  71     epsilon =  0.02620450591493621     steps =  499     ep reward =  500.0
# avg 20 ep rewards :  409.4
# staring ep:  72
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# ep =  72     epsilon =  0.0248942806191894     steps =  499     ep reward =  500.0
# avg 20 ep rewards :  420.65
# staring ep:  73
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# ep =  73     epsilon =  0.023649566588229927     steps =  499     ep reward =  500.0
# avg 20 ep rewards :  430.05
# staring ep:  74
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# ep =  74     epsilon =  0.022467088258818428     steps =  499     ep reward =  500.0
# avg 20 ep rewards :  436.1
# staring ep:  75
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# ep =  75     epsilon =  0.021343733845877507     steps =  499     ep reward =  500.0
# avg 20 ep rewards :  436.1
# staring ep:  76
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# ep =  76     epsilon =  0.02027654715358363     steps =  499     ep reward =  500.0
# avg 20 ep rewards :  436.1
# staring ep:  77
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# ep =  77     epsilon =  0.019262719795904448     steps =  499     ep reward =  500.0
# avg 20 ep rewards :  451.25
# staring ep:  78
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# ep =  78     epsilon =  0.018299583806109226     steps =  270     ep reward =  271.0
# avg 20 ep rewards :  453.0
# staring ep:  79
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# ep =  79     epsilon =  0.017384604615803764     steps =  227     ep reward =  228.0
# avg 20 ep rewards :  451.6
# staring ep:  80
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# ep =  80     epsilon =  0.016515374385013576     steps =  213     ep reward =  214.0
# avg 20 ep rewards :  449.3
# staring ep:  81
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# ep =  81     epsilon =  0.015689605665762895     steps =  252     ep reward =  253.0
# avg 20 ep rewards :  448.3
# staring ep:  82
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# ep =  82     epsilon =  0.01490512538247475     steps =  271     ep reward =  272.0
# avg 20 ep rewards :  436.9
# staring ep:  83
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# ep =  83     epsilon =  0.014159869113351011     steps =  173     ep reward =  174.0
# avg 20 ep rewards :  420.6
# staring ep:  84
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# ep =  84     epsilon =  0.01345187565768346     steps =  95     ep reward =  96.0
# avg 20 ep rewards :  400.4
# staring ep:  85
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# ep =  85     epsilon =  0.012779281874799287     steps =  63     ep reward =  64.0
# avg 20 ep rewards :  378.6
# staring ep:  86
# weights synched
# weights synched
# ep =  86     epsilon =  0.012140317781059323     steps =  11     ep reward =  12.0
# avg 20 ep rewards :  354.2
# staring ep:  87
# weights synched
# ep =  87     epsilon =  0.011533301892006355     steps =  9     ep reward =  10.0
# avg 20 ep rewards :  329.7
# staring ep:  88
# weights synched
# ep =  88     epsilon =  0.010956636797406038     steps =  11     ep reward =  12.0
# avg 20 ep rewards :  305.3
# staring ep:  89
# weights synched
# ep =  89     epsilon =  0.010408804957535735     steps =  9     ep reward =  10.0
# avg 20 ep rewards :  280.8
# staring ep:  90
# weights synched
# ep =  90     epsilon =  0.01     steps =  9     ep reward =  10.0
# avg 20 ep rewards :  256.3
# staring ep:  91
# weights synched
# ep =  91     epsilon =  0.01     steps =  11     ep reward =  12.0
# avg 20 ep rewards :  231.9
# staring ep:  92
# weights synched
# ep =  92     epsilon =  0.01     steps =  10     ep reward =  11.0
# avg 20 ep rewards :  207.45
# staring ep:  93
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# ep =  93     epsilon =  0.01     steps =  163     ep reward =  164.0
# avg 20 ep rewards :  190.65
# staring ep:  94
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# ep =  94     epsilon =  0.01     steps =  295     ep reward =  296.0
# avg 20 ep rewards :  180.45
# staring ep:  95
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# ep =  95     epsilon =  0.01     steps =  198     ep reward =  199.0
# avg 20 ep rewards :  165.4
# staring ep:  96
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# ep =  96     epsilon =  0.01     steps =  325     ep reward =  326.0
# avg 20 ep rewards :  156.7
# staring ep:  97
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# ep =  97     epsilon =  0.01     steps =  185     ep reward =  186.0
# avg 20 ep rewards :  141.0
# staring ep:  98
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# ep =  98     epsilon =  0.01     steps =  169     ep reward =  170.0
# avg 20 ep rewards :  135.95
# staring ep:  99
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched
# weights synched

# %%
# plt.plot(range(150),cum_rewards)
